# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5241, 3084, 12, 6, 195, 2, 3135, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'anarchism', 'term', 'as', 'originated', 'of', 'term']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.

valid_examples = np.array(random.sample(range(valid_window), valid_size))
#valid_examples = np.array([20,40,60,80,30,50,70,90,25,45,65,85,35,55,75,95])

num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001
#num_steps=10001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.327625
# Nearest to such: zal, fictionalized, stf, atlantean, bohr, ably, openbsd, onward,
# Nearest to in: holt, ruthless, doctorow, deceit, kylie, hotspot, butte, lucasfilm,
# Nearest to his: timestamp, tli, multicellular, gillette, tienne, preposition, tortures, rebuttal,
# Nearest to would: fingers, revolt, jacobins, upn, newest, pretentious, modafinil, laminated,
# Nearest to be: costumes, qualities, bombarded, wangenheim, charisma, equally, kalimantan, resulted,
# Nearest to th: outskirts, katherine, rule, brookline, shenandoah, pellets, mollusks, iole,
# Nearest to some: knobs, patrician, animosity, poorer, rolland, imf, transhuman, fairer,
# Nearest to during: butterfield, spc, fam, faculty, shiga, sledge, petitioned, demoscene,
# Nearest to and: renminbi, halakha, mistaking, fab, followings, uproar, mulroney, herc,
# Nearest to more: amplifying, sherbrooke, wisegirls, bassists, glyn, classifies, wildly, kekkonen,
# Nearest to than: lurker, turn, contributes, prescribing, pyre, lena, housework, christy,
# Nearest to see: ange, liz, dividend, voters, blackstone, aclu, breeches, landform,
# Nearest to its: lately, accountant, sultan, newer, contemplative, pga, anmen, artcyclopedia,
# Nearest to used: confining, figurines, increasing, marshallese, redox, lvares, efficiency, programmers,
# Nearest to only: surpasses, oldest, durand, distributors, mughals, lycos, letterbox, units,
# Nearest to up: centimetres, tal, remarked, eca, hermeneutics, miscegenation, mcgovern, nominates,
# Average loss at step 2000: 4.358627
# Average loss at step 4000: 3.863209
# Average loss at step 6000: 3.790063
# Average loss at step 8000: 3.684916
# Average loss at step 10000: 3.617511
# Nearest to such: gmt, onward, fictionalized, well, bohr, lenoir, paulsen, stf,
# Nearest to in: of, on, at, from, for, cryptanalysis, mariner, bending,
# Nearest to his: their, its, the, s, this, langer, tli, her,
# Nearest to would: can, will, could, superimposed, pickups, stylized, trendy, did,
# Nearest to be: have, wangenheim, was, make, mamoru, is, been, coronado,
# Nearest to th: outskirts, four, pellets, katherine, prolonged, murmur, three, iole,
# Nearest to some: many, inker, hamad, expendable, lucas, antiderivatives, verbal, include,
# Nearest to during: from, butterfield, in, spc, faculty, desktops, demoscene, fam,
# Nearest to and: or, but, which, snipers, protists, of, generality, reconquista,
# Nearest to more: less, lebowski, amplifying, talked, coppersmith, warrant, bassists, volkssturm,
# Nearest to than: lurker, tijuana, prescribing, recent, housework, turn, contributes, positron,
# Nearest to see: maastricht, blackstone, hey, reproduced, thumbnail, texan, landform, fortuna,
# Nearest to its: the, his, artcyclopedia, recursion, sideband, augustan, their, converts,
# Nearest to used: increasing, defined, marshallese, found, step, wore, must, known,
# Nearest to only: bundles, surpasses, pieces, units, lead, darpa, hailing, durand,
# Nearest to up: nominates, algae, shawl, several, narbonne, anarchism, details, gorton,
# Average loss at step 12000: 3.606615
# Average loss at step 14000: 3.575056
# Average loss at step 16000: 3.412018
# Average loss at step 18000: 3.453640
# Average loss at step 20000: 3.543003
# Nearest to such: well, known, onward, gmt, endgame, bohr, aptly, other,
# Nearest to in: at, on, from, with, winds, and, doctorow, by,
# Nearest to his: their, her, its, the, tli, helicopters, this, humble,
# Nearest to would: can, will, could, should, may, did, cannot, superimposed,
# Nearest to be: been, have, wangenheim, by, make, take, were, incentives,
# Nearest to th: combatant, outskirts, pellets, three, shenandoah, st, kandahar, pandemics,
# Nearest to some: many, these, all, other, several, inker, any, its,
# Nearest to during: from, butterfield, through, gizzard, in, grandiose, demoscene, haarlem,
# Nearest to and: or, but, which, mariner, in, standout, for, however,
# Nearest to more: less, wildly, mackaye, amplifying, mina, templar, lebowski, peres,
# Nearest to than: or, prescribing, recent, lurker, flax, housework, ellsworth, tijuana,
# Nearest to see: maastricht, texan, reproduced, blackstone, hey, thumbnail, powerhouse, landform,
# Nearest to its: their, his, the, several, sideband, some, fertilizer, artcyclopedia,
# Nearest to used: found, known, increasing, marshallese, wore, defined, described, wastewater,
# Nearest to only: yet, bundles, intents, surpasses, curriculum, naiste, but, torque,
# Nearest to up: into, shawl, etymology, algae, respect, several, miscegenation, nominates,
# Average loss at step 22000: 3.502950
# Average loss at step 24000: 3.487588
# Average loss at step 26000: 3.489097
# Average loss at step 28000: 3.481208
# Average loss at step 30000: 3.500864
# Nearest to such: well, these, gmt, other, known, endgame, bohr, capitan,
# Nearest to in: at, of, on, from, and, during, under, doctorow,
# Nearest to his: their, her, its, the, s, tli, my, whose,
# Nearest to would: can, could, will, should, may, must, cannot, might,
# Nearest to be: have, been, were, wangenheim, being, are, make, incentives,
# Nearest to th: st, one, combatant, bc, outskirts, rd, shenandoah, two,
# Nearest to some: many, these, several, all, various, other, their, any,
# Nearest to during: after, in, through, on, from, whitehaven, reeve, under,
# Nearest to and: or, but, in, akbar, of, energies, who, ayatollah,
# Nearest to more: less, wildly, most, mackaye, fascinated, mohiam, quite, amplifying,
# Nearest to than: flax, slightly, recent, subcultures, libre, ravine, ellsworth, prescribing,
# Nearest to see: hey, maastricht, habitations, serene, turkish, texan, securely, convey,
# Nearest to its: their, his, the, recursion, my, painful, some, her,
# Nearest to used: known, found, described, written, defined, confound, referred, considered,
# Nearest to only: loretta, primarily, yet, bundles, ferreira, season, most, studios,
# Nearest to up: off, them, bayou, into, down, algae, details, slayton,
# Average loss at step 32000: 3.503044
# Average loss at step 34000: 3.498354
# Average loss at step 36000: 3.457809
# Average loss at step 38000: 3.305302
# Average loss at step 40000: 3.424271
# Nearest to such: well, these, known, gmt, endgame, capitan, including, mikhailovich,
# Nearest to in: of, for, resemblances, at, and, from, phosphide, under,
# Nearest to his: their, her, its, my, the, whose, your, helicopters,
# Nearest to would: could, will, can, may, should, must, might, did,
# Nearest to be: been, have, were, are, is, was, being, wangenheim,
# Nearest to th: bc, st, combatant, kandahar, rd, metres, august, wark,
# Nearest to some: many, these, several, any, those, various, their, most,
# Nearest to during: after, on, at, through, against, under, before, upon,
# Nearest to and: or, but, like, in, ishi, radcliffe, clair, ayatollah,
# Nearest to more: less, most, very, mackaye, wildly, quite, fabricate, rather,
# Nearest to than: or, slightly, flax, much, libre, ravine, conseil, nearly,
# Nearest to see: list, hey, refer, newsgroup, texan, serene, maastricht, reproduced,
# Nearest to its: their, his, the, her, spatially, fertilizer, trafficking, latitudes,
# Nearest to used: found, known, considered, described, distinguished, written, referred, defined,
# Nearest to only: locally, primarily, no, polymerization, yet, initially, cumberland, mccourt,
# Nearest to up: off, them, out, into, algae, etymology, him, down,
# Average loss at step 42000: 3.438819
# Average loss at step 44000: 3.452876
# Average loss at step 46000: 3.446305
# Average loss at step 48000: 3.359055
# Average loss at step 50000: 3.384214
# Nearest to such: well, these, known, gmt, mikhailovich, endgame, aptly, many,
# Nearest to in: during, since, from, within, doctorow, of, kia, on,
# Nearest to his: their, her, its, my, the, tli, your, whose,
# Nearest to would: will, could, can, may, should, might, must, cannot,
# Nearest to be: have, was, been, were, being, wangenheim, is, are,
# Nearest to th: bc, st, one, kandahar, ce, alimony, symbolism, rd,
# Nearest to some: many, several, these, various, both, most, any, those,
# Nearest to during: after, in, at, against, through, under, within, around,
# Nearest to and: or, pops, reconnaissance, including, but, s, in, of,
# Nearest to more: less, most, quite, very, highly, wildly, considerations, mackaye,
# Nearest to than: slightly, much, ravine, conseil, flax, expensive, constituting, but,
# Nearest to see: hey, refer, newsgroup, list, odore, ward, include, disparity,
# Nearest to its: their, his, the, fluffy, spatially, fertilizer, her, integrate,
# Nearest to used: found, known, considered, written, referred, defined, available, described,
# Nearest to only: primarily, locally, first, otherwise, polymerization, yet, initially, munro,
# Nearest to up: off, out, them, down, him, algae, aside, proportions,
# Average loss at step 52000: 3.439546
# Average loss at step 54000: 3.425855
# Average loss at step 56000: 3.441581
# Average loss at step 58000: 3.396358
# Average loss at step 60000: 3.390410
# Nearest to such: well, these, known, many, certain, gmt, endgame, follows,
# Nearest to in: within, during, of, on, since, including, at, from,
# Nearest to his: their, her, its, my, whose, your, tli, the,
# Nearest to would: could, will, can, may, should, might, must, cannot,
# Nearest to be: been, wangenheim, have, being, are, was, become, were,
# Nearest to th: bc, five, six, st, eight, four, ce, seven,
# Nearest to some: many, several, these, various, any, most, all, their,
# Nearest to during: after, before, in, following, within, when, against, at,
# Nearest to and: or, but, although, than, however, including, in, while,
# Nearest to more: less, quite, rather, most, wildly, longer, very, mina,
# Nearest to than: much, slightly, and, or, ravine, but, conseil, significantly,
# Nearest to see: refer, newsgroup, but, hey, disparity, can, list, include,
# Nearest to its: their, his, the, her, spatially, our, fluffy, drunken,
# Nearest to used: known, found, defined, considered, available, designed, written, distinguished,
# Nearest to only: primarily, until, first, locally, wet, animalia, watercolor, yet,
# Nearest to up: off, out, them, down, him, algae, aside, etymology,
# Average loss at step 62000: 3.244009
# Average loss at step 64000: 3.254708
# Average loss at step 66000: 3.399486
# Average loss at step 68000: 3.396765
# Average loss at step 70000: 3.357487
# Nearest to such: these, well, known, certain, many, endgame, mikhailovich, clue,
# Nearest to in: within, during, on, from, until, for, doctorow, through,
# Nearest to his: her, their, its, my, whose, your, the, tli,
# Nearest to would: will, could, may, can, should, might, must, cannot,
# Nearest to be: been, were, is, become, was, wangenheim, easily, being,
# Nearest to th: bc, st, ce, seven, rd, otomo, six, cambridge,
# Nearest to some: many, several, these, various, all, most, any, historians,
# Nearest to during: after, before, within, in, following, through, at, bookseller,
# Nearest to and: or, but, while, moria, which, orbis, trimmed, see,
# Nearest to more: less, most, very, rather, quite, wildly, too, highly,
# Nearest to than: slightly, much, but, ravine, conseil, significantly, expensive, dass,
# Nearest to see: refer, but, hey, include, list, nitro, kann, trademark,
# Nearest to its: their, his, the, her, your, fluffy, quotation, our,
# Nearest to used: known, found, described, written, defined, responsible, considered, distinguished,
# Nearest to only: primarily, always, wet, animalia, not, micrometres, yet, no,
# Nearest to up: off, out, them, down, back, him, algae, aside,
# Average loss at step 72000: 3.373157
# Average loss at step 74000: 3.348215
# Average loss at step 76000: 3.313434
# Average loss at step 78000: 3.346141
# Average loss at step 80000: 3.376876
# Nearest to such: well, these, certain, known, follows, shockley, mikhailovich, many,
# Nearest to in: during, within, on, until, at, doctorow, under, of,
# Nearest to his: her, their, my, its, your, our, whose, synodic,
# Nearest to would: could, will, may, might, can, should, must, cannot,
# Nearest to be: been, have, become, being, was, were, easily, refer,
# Nearest to th: bc, ce, nd, rd, st, otomo, five, seven,
# Nearest to some: many, several, most, various, these, their, any, aafc,
# Nearest to during: after, in, before, when, while, within, throughout, on,
# Nearest to and: or, including, but, presumes, while, archangels, until, carolla,
# Nearest to more: less, very, quite, most, rather, wildly, too, highly,
# Nearest to than: ravine, slightly, much, niro, significantly, while, hollow, navigator,
# Nearest to see: refer, but, newsgroup, hey, include, list, es, earley,
# Nearest to its: their, his, her, your, our, fluffy, integrate, quotation,
# Nearest to used: known, defined, found, available, considered, described, written, seen,
# Nearest to only: always, until, primarily, animalia, watercolor, forty, first, observational,
# Nearest to up: off, out, them, down, him, aside, algae, cash,
# Average loss at step 82000: 3.408524
# Average loss at step 84000: 3.410772
# Average loss at step 86000: 3.389767
# Average loss at step 88000: 3.355041
# Average loss at step 90000: 3.364944
# Nearest to such: well, known, certain, these, follows, gmt, mikhailovich, shockley,
# Nearest to in: during, within, under, around, with, kia, of, between,
# Nearest to his: her, their, its, your, my, our, whose, tli,
# Nearest to would: could, will, may, might, can, should, must, cannot,
# Nearest to be: been, have, become, was, is, refer, being, produce,
# Nearest to th: st, bc, seven, nd, ce, one, rd, eight,
# Nearest to some: many, several, any, these, all, certain, various, most,
# Nearest to during: after, in, while, before, at, against, until, when,
# Nearest to and: or, but, akbar, while, including, although, in, bertolucci,
# Nearest to more: less, rather, very, quite, most, wildly, highly, too,
# Nearest to than: slightly, ravine, much, significantly, hollow, niro, conseil, dass,
# Nearest to see: list, refer, but, hey, ward, include, jurgen, gazetteer,
# Nearest to its: their, his, her, your, the, fluffy, our, spatially,
# Nearest to used: found, known, considered, defined, described, applied, referred, designed,
# Nearest to only: no, animalia, primarily, every, spooky, always, forty, observational,
# Nearest to up: off, out, down, them, him, back, aside, together,
# Average loss at step 92000: 3.403216
# Average loss at step 94000: 3.251930
# Average loss at step 96000: 3.356319
# Average loss at step 98000: 3.241765
# Average loss at step 100000: 3.351567
# Nearest to such: known, well, certain, follows, these, many, including, disguised,
# Nearest to in: during, within, until, on, under, from, of, among,
# Nearest to his: her, their, your, my, our, its, the, tli,
# Nearest to would: will, could, might, may, should, can, must, cannot,
# Nearest to be: been, become, refer, being, is, are, have, produce,
# Nearest to th: bc, ce, nd, rd, st, one, codify, otomo,
# Nearest to some: many, several, any, these, all, various, certain, aafc,
# Nearest to during: after, in, before, throughout, against, until, through, following,
# Nearest to and: or, but, while, who, including, like, although, when,
# Nearest to more: less, very, most, quite, rather, wildly, better, highly,
# Nearest to than: or, slightly, much, and, ravine, niro, while, significantly,
# Nearest to see: list, refer, references, ward, include, jurgen, but, newsgroup,
# Nearest to its: their, his, her, your, the, spatially, integrate, our,
# Nearest to used: found, defined, described, considered, known, applied, written, designed,
# Nearest to only: animalia, primarily, forty, until, dipyramid, not, no, revising,
# Nearest to up: off, out, down, him, them, back, respect, heaven,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
